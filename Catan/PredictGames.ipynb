# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
#columns=['SCHL', 'PINCP', 'NATIVITY', 'SEX']
#population = pd.read_csv("data/pums/ss13pusa.csv",usecols=(columns), nrows=1000000)
data = pd.read_csv("data/catan.csv")

# %%
data
# Out:
#      gameNum  player  points   me  2  3  4   5   6   7       ...        \
# 0          1       1       5  NaN  1  3  5   8   7  10       ...
# 1          1       2       9  1.0  1  3  5   8   7  10       ...
# 2          1       3      10  NaN  1  3  5   8   7  10       ...
# 3          1       4       5  NaN  1  3  5   8   7  10       ...
# 4          2       1      10  NaN  1  6  3   9  10   8       ...
# 5          2       2       6  NaN  1  6  3   9  10   8       ...
# 6          2       3       4  1.0  1  6  3   9  10   8       ...
# 7          2       4       9  NaN  1  6  3   9  10   8       ...
# 8          3       1       5  NaN  0  3  3  10  10   4       ...
# 9          3       2      10  NaN  0  3  3  10  10   4       ...
# 10         3       3       7  1.0  0  3  3  10  10   4       ...
# 11         3       4       7  NaN  0  3  3  10  10   4       ...
# 12         4       1       7  NaN  1  6  5  12  14  20       ...
# 13         4       2      10  1.0  1  6  5  12  14  20       ...
# 14         4       3       9  NaN  1  6  5  12  14  20       ...
# 15         4       4       9  NaN  1  6  5  12  14  20       ...
# 16         5       1       8  1.0  1  3  7   9  12  14       ...
# 17         5       2      10  NaN  1  3  7   9  12  14       ...
# 18         5       3       3  NaN  1  3  7   9  12  14       ...
# 19         5       4       7  NaN  1  3  7   9  12  14       ...
# 20         6       1       6  1.0  0  4  6   6   8   4       ...
# 21         6       2       6  NaN  0  4  6   6   8   4       ...
# 22         6       3       6  NaN  0  4  6   6   8   4       ...
# 23         6       4      10  NaN  0  4  6   6   8   4       ...
# 24         7       1      10  1.0  2  4  5   5   5   9       ...
# 25         7       2       6  NaN  2  4  5   5   5   9       ...
# 26         7       3       4  NaN  2  4  5   5   5   9       ...
# 27         7       4       4  NaN  2  4  5   5   5   9       ...
# 28         8       1       8  NaN  3  0  4   7   6   9       ...
# 29         8       2      11  NaN  3  0  4   7   6   9       ...
# ..       ...     ...     ...  ... .. .. ..  ..  ..  ..       ...
# 170       43       3       8  NaN  1  0  4   8  11  10       ...
# 171       43       4       2  NaN  1  0  4   8  11  10       ...
# 172       44       1       8  1.0  4  5  6   5  12  20       ...
# 173       44       2       5  NaN  4  5  6   5  12  20       ...
# 174       44       3      10  NaN  4  5  6   5  12  20       ...
# 175       44       4       9  NaN  4  5  6   5  12  20       ...
# 176       45       1       7  NaN  0  3  3   7   6   7       ...
# 177       45       2      10  NaN  0  3  3   7   6   7       ...
# 178       45       3       6  1.0  0  3  3   7   6   7       ...
# 179       45       4       6  NaN  0  3  3   7   6   7       ...
# 180       46       1       5  1.0  3  6  5   9  13  14       ...
# 181       46       2       6  NaN  3  6  5   9  13  14       ...
# 182       46       3      10  NaN  3  6  5   9  13  14       ...
# 183       46       4       8  NaN  3  6  5   9  13  14       ...
# 184       47       1       5  NaN  1  4  5   6  11   5       ...
# 185       47       2      12  1.0  1  4  5   6  11   5       ...
# 186       47       3       6  NaN  1  4  5   6  11   5       ...
# 187       47       4       6  NaN  1  4  5   6  11   5       ...
# 188       48       1      11  1.0  0  6  7   7  10   6       ...
# 189       48       2       9  NaN  0  6  7   7  10   6       ...
# 190       48       3       6  NaN  0  6  7   7  10   6       ...
# 191       48       4       7  NaN  0  6  7   7  10   6       ...
# 192       49       1       4  NaN  0  5  3   6  13  13       ...
# 193       49       2      10  NaN  0  5  3   6  13  13       ...
# 194       49       3       4  1.0  0  5  3   6  13  13       ...
# 195       49       4       5  NaN  0  5  3   6  13  13       ...
# 196       50       1       5  NaN  1  7  4   5   7  17       ...
# 197       50       2      10  1.0  1  7  4   5   7  17       ...
# 198       50       3       4  NaN  1  7  4   5   7  17       ...
# 199       50       4       8  NaN  1  7  4   5   7  17       ...
#
#      Unnamed: 26  production  tradeGain  robberCardsGain  totalGain  \
# 0              O          38          5                2         45
# 1              O          48          8                6         62
# 2              C          44         14                9         67
# 3              S          42         12                0         54
# 4             2L          60         15               16         91
# 5              W          57         12                1         70
# 6              L          44         10                8         62
# 7              S          61         16               11         88
# 8              S          44          5                5         54
# 9              S          41          4                9         54
# 10            3G          47          6                5         58
# 11             L          53          2                2         57
# 12            3G          64         15               12         91
# 13             C          97         21               15        133
# 14             W          61         18                7         86
# 15             O          75         11                8         94
# 16            2S          70         17                5         92
# 17             L          56          4               16         76
# 18             D          30          2                7         39
# 19             C          48          4                5         57
# 20             C          48          6                3         57
# 21            3G          35          7                2         44
# 22             W          35          2                1         38
# 23             O          56          7                9         72
# 24             W          43          9               13         65
# 25             W          31          5               11         47
# 26             W          31          1                4         36
# 27             S          30          5                5         40
# 28             S          48          6                1         55
# 29             S          61         10                9         80
# ..           ...         ...        ...              ...        ...
# 170            O          71         11                5         87
# 171            C          31          7                9         47
# 172            O          86         17               12        115
# 173            S          47          9               16         72
# 174            W          77         19                7        103
# 175            S          56         13                4         73
# 176            L          46         10                2         58
# 177            L          55          7               11         73
# 178            W          26          4                5         35
# 179            S          47          2                4         53
# 180           3G          36          6                6         48
# 181            D          53          8                4         65
# 182           2S          46          9               10         65
# 183            C          70          7                6         83
# 184           2O          32         12                2         46
# 185            S          61          7               11         79
# 186            O          43          6                4         53
# 187            S          37          7                0         44
# 188            C          72          9               13         94
# 189            L          67         10                1         78
# 190            L          43          7               12         62
# 191            L          31          3                0         34
# 192            S          47          6                5         58
# 193            S          77         15                5         97
# 194           2W          29          9                8         46
# 195            S          41          8               11         60
# 196            C          41          6                7         54
# 197            C          64          5                9         78
# 198            S          44          7                4         55
# 199            C          57          3                5         65
#
#      tradeLoss robberCardsLoss  tribute totalLoss  totalAvailable
# 0           10               2        4        16              29
# 1           11               1        8        20              42
# 2           24               4        0        28              39
# 3           24               6        0        30              24
# 4           28              10        0        38              53
# 5           26               6        8        40              30
# 6           18               6        8        32              30
# 7           25               6        4        35              53
# 8           11               1        9        21              33
# 9            8               3        0        11              43
# 10          10               7        0        17              41
# 11           4               4        8        16              41
# 12          23               5       12        40              51
# 13          47              15       10        72              61
# 14          33               5        0        38              48
# 15          37              19        0        56              38
# 16          33              11        0        44              48
# 17          14               7        4        25              51
# 18           5               4        4        13              26
# 19           6              10        9        25              32
# 20          13               1        0        14              43
# 21          13               3        0        16              28
# 22           6               1        4        11              27
# 23          18               2        4        24              48
# 24          19               6        0        25              40
# 25          14               1        0        15              32
# 26           4              11        0        15              21
# 27          10               9        0        19              21
# 28          10               9        0        19              36
# 29          16               2        4        22              58
# ..         ...             ...      ...       ...             ...
# 170         26               8        8        42              45
# 171         10               0       14        24              23
# 172         43              15        4        62              53
# 173         16               8        8        32              40
# 174         47               8        4        59              44
# 175         29               0        4        33              40
# 176         25               4        0        29              29
# 177         15               8        0        23              50
# 178          4               0        4         8              27
# 179          5               4        6        15              38
# 180         11               6        0        17              31
# 181         18               7        4        29              36
# 182         14               4        0        18              47
# 183         14               3       33        50              33
# 184         23               1        0        24              22
# 185         19               4        0        23              56
# 186         14               2        5        21              32
# 187         16               2        4        22              22
# 188         23               8        4        35              59
# 189         28               9        0        37              41
# 190          7               2        0         9              53
# 191          6               1        0         7              27
# 192         17               5        8        30              28
# 193         33               9        8        50              47
# 194         10               5        8        23              23
# 195         22               4        0        26              34
# 196         14               6        4        24              30
# 197         15               6       10        31              47
# 198         22               1        8        31              24
# 199          2              12        8        22              43
#
# [200 rows x 36 columns]
